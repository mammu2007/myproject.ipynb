# %% [markdown]
# <a href="https://colab.research.google.com/github/mammu2007/myproject.ipynb/blob/main/day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample messy sales dataset
data = {
    'Product': ['Laptop', 'Mobile', 'Tablet', None, 'Laptop'],
    'Quantity': [2, 3, None, 5, 2],
    'Price': [50000, 20000, 15000, None, 50000]
}

df = pd.DataFrame(data)

print("Original Dataset:")
print(df)

# Handle missing values
df['Product'].fillna('Unknown', inplace=True)
df['Quantity'].fillna(df['Quantity'].mean(), inplace=True)
df['Price'].fillna(df['Price'].mean(), inplace=True)

# Remove duplicate rows
df.drop_duplicates(inplace=True)

print("\nCleaned Dataset:")
print(df)

# %%
import matplotlib.pyplot as plt

months=["jan","Feb","Mar","Apr","May"]

sales=[10000,25000,30000,45000,50000]

plt.plot(months,sales)

plt.xlabel("months")

plt.ylabel("sales")

plt.title("sales amount")

plt.show()

# %%
import matplotlib.pyplot as plt

Students=["A","B","C","D","E"]

Marks=[100,90,45,70,85]

plt.bar(Students,Marks)

plt.xlabel("Student Marks")

plt.ylabel("Student")

plt.title("Marks")

plt.show()
