# %% [markdown]
# <a href="https://colab.research.google.com/github/mammu2007/myproject.ipynb/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1=int(input("enter mark1:"))
mark2=int(input("enter mark2:"))
mark3=int(input("enter mark3:"))

total=mark1+mark2+mark3
Average=total/3
656

print("total :",total)
print("average:",Average)

if Average>=50:
  print("pass")
else:
  print("fail")
# Out:
# enter mark1:65
# enter mark2:76
# enter mark3:54
# total : 195
# average: 65.0
# pass
