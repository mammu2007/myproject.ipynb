# %% [markdown]
# <a href="https://colab.research.google.com/github/mammu2007/myproject.ipynb/blob/main/numpy_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks=np.array([90,85,78,92])

print(marks)
print("Mean of marks:", np.mean(marks))
# Out:
# [90 85 78 92]

# %%
import numpy as np

students = np.array([
    [90,85],
    [78,92],
    [88,95]
])
print(students)
# Out:
# [[90 85]
#  [78 92]
#  [88 95]]

# %%
import numpy as np
arr = np.zeros((1,2))
print(arr)
# Out:
# [[0. 0.]]

# %%
try:
  num=int(input("enter number:"))
  print(num)

except:
  print("invalid input")
# Out:
# enter number:23
# 23
