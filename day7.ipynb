# %% [markdown]
# <a href="https://colab.research.google.com/github/mammu2007/myproject.ipynb/blob/main/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

employees = {
    "Emp_ID": [101, 102, 103, 104, 105],
    "Name": ["Arun", "Priya", "Rahul", "Divya", "Kumar"],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [45000, 40000, 50000, 55000, 42000],
    "Experience": [2, 3, 5, 6, 4]
}

df = pd.DataFrame(employees)

print("Employee Dataset")
print(df)

print("\nAverage Salary")
print(df["Salary"].mean())

print("\nHighest Salary")
print(df["Salary"].max())

print("\nEmployees in HR")
print(df[df["Department"] == "HR"])

print("\nEmployees with Experience > 3")
print(df[df["Experience"] > 3])

print("\nEmployee Count by Department")
print(df["Department"].value_counts())

# %%
import pandas as pd

data = {
    'Name': ['John', 'Mary', 'John'],
    'Sales': [1000, 1500, 1000]
}

df = pd.DataFrame(data)

print(df.duplicated())

# %%
import pandas as pd

data = {
    'emp_nm': ['John', 'Mary'],
    'emp_sal': [25000, 30000]
}

df = pd.DataFrame(data)

df.rename(columns={
    'emp_nm': 'Employee Name',
    'emp_sal': 'Employee Salary'
}, inplace=True)

print(df)

# %%
import pandas as pd

data = {
    "Region":["South","North","West","Eest","South","North"],
    "Product":["Laptop","Mobile","Laptop","Tabels","Mobiles","Tablets"],
    "Sales":[5000,3000,4500,2500,2000,3500]
}

df= pd.DataFrame(data)

print(df)

# %%
south_sales=df[df["Region"]=="South"]

print(south_sales)

# %%
sorted_df = df.sort_values("Sales")

print(sorted_df)
